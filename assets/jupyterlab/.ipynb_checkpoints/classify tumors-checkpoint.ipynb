# %%
import pandas as pd

df = pd.read_csv('/project_data/data_asset/BreastCancerWisconsinDataSet.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
df.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 564  ...        25.450          26.40           166.10      2027.0
# 565  ...        23.690          38.25           155.00      1731.0
# 566  ...        18.980          34.12           126.70      1124.0
# 567  ...        25.740          39.42           184.60      1821.0
# 568  ...         9.456          30.37            59.16       268.6
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
# [5 rows x 32 columns]

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# count     569.000000  ...    569.000000     569.000000       569.000000
# mean        0.181162  ...     16.269190      25.677223       107.261213
# std         0.027414  ...      4.833242       6.146258        33.602542
# min         0.106000  ...      7.930000      12.020000        50.410000
# 25%         0.161900  ...     13.010000      21.080000        84.110000
# 50%         0.179200  ...     14.970000      25.410000        97.660000
# 75%         0.195700  ...     18.790000      29.720000       125.400000
# max         0.304000  ...     36.040000      49.540000       251.200000
#
#         area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# count   569.000000        569.000000         569.000000       569.000000
# mean    880.583128          0.132369           0.254265         0.272188
# std     569.356993          0.022832           0.157336         0.208624
# min     185.200000          0.071170           0.027290         0.000000
# 25%     515.300000          0.116600           0.147200         0.114500
# 50%     686.500000          0.131300           0.211900         0.226700
# 75%    1084.000000          0.146000           0.339100         0.382900
# max    4254.000000          0.222600           1.058000         1.252000
#
#        concave points_worst  symmetry_worst  fractal_dimension_worst
# count            569.000000      569.000000               569.000000
# mean               0.114606        0.290076                 0.083946
# std                0.065732        0.061867                 0.018061
# min                0.000000        0.156500                 0.055040
# 25%                0.064930        0.250400                 0.071460
# 50%                0.099930        0.282200                 0.080040
# 75%                0.161400        0.317900                 0.092080
# max                0.291000        0.663800                 0.207500
#
# [8 rows x 31 columns]

# %%
# Distribution of target values/labels.
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
# Check for NANs.
df.isnull().sum().sum()
# Out:
# 0

# %%
# pairwise correlation of numerical columns
df.corr()
# Out:
#                                id  radius_mean  texture_mean  perimeter_mean  \
# id                       1.000000     0.074626      0.099770        0.073159
# radius_mean              0.074626     1.000000      0.323782        0.997855
# texture_mean             0.099770     0.323782      1.000000        0.329533
# perimeter_mean           0.073159     0.997855      0.329533        1.000000
# area_mean                0.096893     0.987357      0.321086        0.986507
# smoothness_mean         -0.012968     0.170581     -0.023389        0.207278
# compactness_mean         0.000096     0.506124      0.236702        0.556936
# concavity_mean           0.050080     0.676764      0.302418        0.716136
# concave points_mean      0.044158     0.822529      0.293464        0.850977
# symmetry_mean           -0.022114     0.147741      0.071401        0.183027
# fractal_dimension_mean  -0.052511    -0.311631     -0.076437       -0.261477
# radius_se                0.143048     0.679090      0.275869        0.691765
# texture_se              -0.007526    -0.097317      0.386358       -0.086761
# perimeter_se             0.137331     0.674172      0.281673        0.693135
# area_se                  0.177742     0.735864      0.259845        0.744983
# smoothness_se            0.096781    -0.222600      0.006614       -0.202694
# compactness_se           0.033961     0.206000      0.191975        0.250744
# concavity_se             0.055239     0.194204      0.143293        0.228082
# concave points_se        0.078768     0.376169      0.163851        0.407217
# symmetry_se             -0.017306    -0.104321      0.009127       -0.081629
# fractal_dimension_se     0.025725    -0.042641      0.054458       -0.005523
# radius_worst             0.082405     0.969539      0.352573        0.969476
# texture_worst            0.064720     0.297008      0.912045        0.303038
# perimeter_worst          0.079986     0.965137      0.358040        0.970387
# area_worst               0.107187     0.941082      0.343546        0.941550
# smoothness_worst         0.010338     0.119616      0.077503        0.150549
# compactness_worst       -0.002968     0.413463      0.277830        0.455774
# concavity_worst          0.023203     0.526911      0.301025        0.563879
# concave points_worst     0.035174     0.744214      0.295316        0.771241
# symmetry_worst          -0.044224     0.163953      0.105008        0.189115
# fractal_dimension_worst -0.029866     0.007066      0.119205        0.051019
#
#                          area_mean  smoothness_mean  compactness_mean  \
# id                        0.096893        -0.012968          0.000096
# radius_mean               0.987357         0.170581          0.506124
# texture_mean              0.321086        -0.023389          0.236702
# perimeter_mean            0.986507         0.207278          0.556936
# area_mean                 1.000000         0.177028          0.498502
# smoothness_mean           0.177028         1.000000          0.659123
# compactness_mean          0.498502         0.659123          1.000000
# concavity_mean            0.685983         0.521984          0.883121
# concave points_mean       0.823269         0.553695          0.831135
# symmetry_mean             0.151293         0.557775          0.602641
# fractal_dimension_mean   -0.283110         0.584792          0.565369
# radius_se                 0.732562         0.301467          0.497473
# texture_se               -0.066280         0.068406          0.046205
# perimeter_se              0.726628         0.296092          0.548905
# area_se                   0.800086         0.246552          0.455653
# smoothness_se            -0.166777         0.332375          0.135299
# compactness_se            0.212583         0.318943          0.738722
# concavity_se              0.207660         0.248396          0.570517
# concave points_se         0.372320         0.380676          0.642262
# symmetry_se              -0.072497         0.200774          0.229977
# fractal_dimension_se     -0.019887         0.283607          0.507318
# radius_worst              0.962746         0.213120          0.535315
# texture_worst             0.287489         0.036072          0.248133
# perimeter_worst           0.959120         0.238853          0.590210
# area_worst                0.959213         0.206718          0.509604
# smoothness_worst          0.123523         0.805324          0.565541
# compactness_worst         0.390410         0.472468          0.865809
# concavity_worst           0.512606         0.434926          0.816275
# concave points_worst      0.722017         0.503053          0.815573
# symmetry_worst            0.143570         0.394309          0.510223
# fractal_dimension_worst   0.003738         0.499316          0.687382
#
#                          concavity_mean  concave points_mean  symmetry_mean  \
# id                             0.050080             0.044158      -0.022114
# radius_mean                    0.676764             0.822529       0.147741
# texture_mean                   0.302418             0.293464       0.071401
# perimeter_mean                 0.716136             0.850977       0.183027
# area_mean                      0.685983             0.823269       0.151293
# smoothness_mean                0.521984             0.553695       0.557775
# compactness_mean               0.883121             0.831135       0.602641
# concavity_mean                 1.000000             0.921391       0.500667
# concave points_mean            0.921391             1.000000       0.462497
# symmetry_mean                  0.500667             0.462497       1.000000
# fractal_dimension_mean         0.336783             0.166917       0.479921
# radius_se                      0.631925             0.698050       0.303379
# texture_se                     0.076218             0.021480       0.128053
# perimeter_se                   0.660391             0.710650       0.313893
# area_se                        0.617427             0.690299       0.223970
# smoothness_se                  0.098564             0.027653       0.187321
# compactness_se                 0.670279             0.490424       0.421659
# concavity_se                   0.691270             0.439167       0.342627
# concave points_se              0.683260             0.615634       0.393298
# symmetry_se                    0.178009             0.095351       0.449137
# fractal_dimension_se           0.449301             0.257584       0.331786
# radius_worst                   0.688236             0.830318       0.185728
# texture_worst                  0.299879             0.292752       0.090651
# perimeter_worst                0.729565             0.855923       0.219169
# area_worst                     0.675987             0.809630       0.177193
# smoothness_worst               0.448822             0.452753       0.426675
# compactness_worst              0.754968             0.667454       0.473200
# concavity_worst                0.884103             0.752399       0.433721
# concave points_worst           0.861323             0.910155       0.430297
# symmetry_worst                 0.409464             0.375744       0.699826
# fractal_dimension_worst        0.514930             0.368661       0.438413
#
#                          ...  radius_worst  texture_worst  perimeter_worst  \
# id                       ...      0.082405       0.064720         0.079986
# radius_mean              ...      0.969539       0.297008         0.965137
# texture_mean             ...      0.352573       0.912045         0.358040
# perimeter_mean           ...      0.969476       0.303038         0.970387
# area_mean                ...      0.962746       0.287489         0.959120
# smoothness_mean          ...      0.213120       0.036072         0.238853
# compactness_mean         ...      0.535315       0.248133         0.590210
# concavity_mean           ...      0.688236       0.299879         0.729565
# concave points_mean      ...      0.830318       0.292752         0.855923
# symmetry_mean            ...      0.185728       0.090651         0.219169
# fractal_dimension_mean   ...     -0.253691      -0.051269        -0.205151
# radius_se                ...      0.715065       0.194799         0.719684
# texture_se               ...     -0.111690       0.409003        -0.102242
# perimeter_se             ...      0.697201       0.200371         0.721031
# area_se                  ...      0.757373       0.196497         0.761213
# smoothness_se            ...     -0.230691      -0.074743        -0.217304
# compactness_se           ...      0.204607       0.143003         0.260516
# concavity_se             ...      0.186904       0.100241         0.226680
# concave points_se        ...      0.358127       0.086741         0.394999
# symmetry_se              ...     -0.128121      -0.077473        -0.103753
# fractal_dimension_se     ...     -0.037488      -0.003195        -0.001000
# radius_worst             ...      1.000000       0.359921         0.993708
# texture_worst            ...      0.359921       1.000000         0.365098
# perimeter_worst          ...      0.993708       0.365098         1.000000
# area_worst               ...      0.984015       0.345842         0.977578
# smoothness_worst         ...      0.216574       0.225429         0.236775
# compactness_worst        ...      0.475820       0.360832         0.529408
# concavity_worst          ...      0.573975       0.368366         0.618344
# concave points_worst     ...      0.787424       0.359755         0.816322
# symmetry_worst           ...      0.243529       0.233027         0.269493
# fractal_dimension_worst  ...      0.093492       0.219122         0.138957
#
#                          area_worst  smoothness_worst  compactness_worst  \
# id                         0.107187          0.010338          -0.002968
# radius_mean                0.941082          0.119616           0.413463
# texture_mean               0.343546          0.077503           0.277830
# perimeter_mean             0.941550          0.150549           0.455774
# area_mean                  0.959213          0.123523           0.390410
# smoothness_mean            0.206718          0.805324           0.472468
# compactness_mean           0.509604          0.565541           0.865809
# concavity_mean             0.675987          0.448822           0.754968
# concave points_mean        0.809630          0.452753           0.667454
# symmetry_mean              0.177193          0.426675           0.473200
# fractal_dimension_mean    -0.231854          0.504942           0.458798
# radius_se                  0.751548          0.141919           0.287103
# texture_se                -0.083195         -0.073658          -0.092439
# perimeter_se               0.730713          0.130054           0.341919
# area_se                    0.811408          0.125389           0.283257
# smoothness_se             -0.182195          0.314457          -0.055558
# compactness_se             0.199371          0.227394           0.678780
# concavity_se               0.188353          0.168481           0.484858
# concave points_se          0.342271          0.215351           0.452888
# symmetry_se               -0.110343         -0.012662           0.060255
# fractal_dimension_se      -0.022736          0.170568           0.390159
# radius_worst               0.984015          0.216574           0.475820
# texture_worst              0.345842          0.225429           0.360832
# perimeter_worst            0.977578          0.236775           0.529408
# area_worst                 1.000000          0.209145           0.438296
# smoothness_worst           0.209145          1.000000           0.568187
# compactness_worst          0.438296          0.568187           1.000000
# concavity_worst            0.543331          0.518523           0.892261
# concave points_worst       0.747419          0.547691           0.801080
# symmetry_worst             0.209146          0.493838           0.614441
# fractal_dimension_worst    0.079647          0.617624           0.810455
#
#                          concavity_worst  concave points_worst  \
# id                              0.023203              0.035174
# radius_mean                     0.526911              0.744214
# texture_mean                    0.301025              0.295316
# perimeter_mean                  0.563879              0.771241
# area_mean                       0.512606              0.722017
# smoothness_mean                 0.434926              0.503053
# compactness_mean                0.816275              0.815573
# concavity_mean                  0.884103              0.861323
# concave points_mean             0.752399              0.910155
# symmetry_mean                   0.433721              0.430297
# fractal_dimension_mean          0.346234              0.175325
# radius_se                       0.380585              0.531062
# texture_se                     -0.068956             -0.119638
# perimeter_se                    0.418899              0.554897
# area_se                         0.385100              0.538166
# smoothness_se                  -0.058298             -0.102007
# compactness_se                  0.639147              0.483208
# concavity_se                    0.662564              0.440472
# concave points_se               0.549592              0.602450
# symmetry_se                     0.037119             -0.030413
# fractal_dimension_se            0.379975              0.215204
# radius_worst                    0.573975              0.787424
# texture_worst                   0.368366              0.359755
# perimeter_worst                 0.618344              0.816322
# area_worst                      0.543331              0.747419
# smoothness_worst                0.518523              0.547691
# compactness_worst               0.892261              0.801080
# concavity_worst                 1.000000              0.855434
# concave points_worst            0.855434              1.000000
# symmetry_worst                  0.532520              0.502528
# fractal_dimension_worst         0.686511              0.511114
#
#                          symmetry_worst  fractal_dimension_worst
# id                            -0.044224                -0.029866
# radius_mean                    0.163953                 0.007066
# texture_mean                   0.105008                 0.119205
# perimeter_mean                 0.189115                 0.051019
# area_mean                      0.143570                 0.003738
# smoothness_mean                0.394309                 0.499316
# compactness_mean               0.510223                 0.687382
# concavity_mean                 0.409464                 0.514930
# concave points_mean            0.375744                 0.368661
# symmetry_mean                  0.699826                 0.438413
# fractal_dimension_mean         0.334019                 0.767297
# radius_se                      0.094543                 0.049559
# texture_se                    -0.128215                -0.045655
# perimeter_se                   0.109930                 0.085433
# area_se                        0.074126                 0.017539
# smoothness_se                 -0.107342                 0.101480
# compactness_se                 0.277878                 0.590973
# concavity_se                   0.197788                 0.439329
# concave points_se              0.143116                 0.310655
# symmetry_se                    0.389402                 0.078079
# fractal_dimension_se           0.111094                 0.591328
# radius_worst                   0.243529                 0.093492
# texture_worst                  0.233027                 0.219122
# perimeter_worst                0.269493                 0.138957
# area_worst                     0.209146                 0.079647
# smoothness_worst               0.493838                 0.617624
# compactness_worst              0.614441                 0.810455
# concavity_worst                0.532520                 0.686511
# concave points_worst           0.502528                 0.511114
# symmetry_worst                 1.000000                 0.537848
# fractal_dimension_worst        0.537848                 1.000000
#
# [31 rows x 31 columns]

# %%
# Import seaborn and matplotlib for data exploration/visialization.
# !pip install --upgrade seaborn

import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Requirement already up-to-date: seaborn in /opt/conda/envs/Python-3.6/lib/python3.6/site-packages (0.9.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.14.0 in /opt/conda/envs/Python-3.6/lib/python3.6/site-packages (from seaborn) (1.2.0)
# Requirement already satisfied, skipping upgrade: pandas>=0.15.2 in /opt/conda/envs/Python-3.6/lib/python3.6/site-packages (from seaborn) (0.24.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.3 in /opt/conda/envs/Python-3.6/lib/python3.6/site-packages (from seaborn) (1.15.4)
# Requirement already satisfied, skipping upgrade: matplotlib>=1.4.3 in /opt/conda/envs/Python-3.6/lib/python3.6/site-packages (from seaborn) (3.0.2)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.5.0 in /opt/conda/envs/Python-3.6/lib/python3.6/site-packages (from pandas>=0.15.2->seaborn) (2.7.5)
# Requirement already satisfied, skipping upgrade: pytz>=2011k in /opt/conda/envs/Python-3.6/lib/python3.6/site-packages (from pandas>=0.15.2->seaborn) (2018.9)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /opt/conda/envs/Python-3.6/lib/python3.6/site-packages (from matplotlib>=1.4.3->seaborn) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /opt/conda/envs/Python-3.6/lib/python3.6/site-packages (from matplotlib>=1.4.3->seaborn) (1.0.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /opt/conda/envs/Python-3.6/lib/python3.6/site-packages (from matplotlib>=1.4.3->seaborn) (2.3.1)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /opt/conda/envs/Python-3.6/lib/python3.6/site-packages (from python-dateutil>=2.5.0->pandas>=0.15.2->seaborn) (1.12.0)
# Requirement already satisfied, skipping upgrade: setuptools in /opt/conda/envs/Python-3.6/lib/python3.6/site-packages (from kiwisolver>=1.0.1->matplotlib>=1.4.3->seaborn) (40.8.0)

# %%
#plot a correlation heatmap
plt.subplots(figsize=(25,20))
hm1 = sns.heatmap(df.corr(), annot=True, cmap='YlGnBu')
hm1.set_xticklabels(hm1.get_xticklabels(), rotation=90)
hm1.xaxis.set_ticks_position('top')

# %%
# plot boxplots of numerical columns
cont_list = ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'symmetry_mean', 'fractal_dimension_mean']
f, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9)) = plt.subplots(3, 3, figsize=(20, 25))
ax = [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9]

for i in range(len(cont_list)):
    sns.boxplot(x = 'diagnosis', y = cont_list[i], data=df, ax=ax[i])

# %%
# Choosing the significant predictors.

X = df.iloc[:, [2,7,24,26]]
X = X.values

# Changing the target variables to binary variables
y = (df['diagnosis'] == 'M').astype(int)
y = y.values

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
X
# Out:
# array([[1.799e+01, 2.776e-01, 1.846e+02, 1.622e-01],
#        [2.057e+01, 7.864e-02, 1.588e+02, 1.238e-01],
#        [1.969e+01, 1.599e-01, 1.525e+02, 1.444e-01],
#        ...,
#        [1.660e+01, 1.023e-01, 1.267e+02, 1.139e-01],
#        [2.060e+01, 2.770e-01, 1.846e+02, 1.650e-01],
#        [7.760e+00, 4.362e-02, 5.916e+01, 8.996e-02]])

# %%
# Split the data set and create two data sets.
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35, random_state=143)

# %%
# List the number of records in each data set.
print('Number of training records: ' + str(len(X_train)))
print('Number of testing records : ' + str(len(X_test)))
# Out:
# Number of training records: 369
# Number of testing records : 200

# %%
# !pip install 'xgboost==0.80'
import xgboost
xgboost.__version__
# Out:
# Requirement already satisfied: xgboost==0.80 in /opt/conda/envs/Python-3.6/lib/python3.6/site-packages (0.80)
# Requirement already satisfied: scipy in /opt/conda/envs/Python-3.6/lib/python3.6/site-packages (from xgboost==0.80) (1.2.0)
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.6/lib/python3.6/site-packages (from xgboost==0.80) (1.15.4)
# '0.80'

# %%
# Import packages you need to create the XGBoost model.
from xgboost.sklearn import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

# %%
# Create the XGB classifier - xgb_model.
xgb_model = XGBClassifier(n_estimators=100)

# %%
# List the default parameters.
print(xgb_model.get_xgb_params())
# Out:
# {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bytree': 1, 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 1, 'missing': None, 'n_estimators': 100, 'nthread': 1, 'objective': 'binary:logistic', 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'silent': 1, 'subsample': 1}

# %%
# Train and evaluate.
xgb_model.fit(X_train, y_train, eval_metric=['error'], eval_set=[((X_train, y_train)),(X_test, y_test)])
# Out:
# [0]	validation_0-error:0.03794	validation_1-error:0.05
# [1]	validation_0-error:0.03794	validation_1-error:0.05
# [2]	validation_0-error:0.03794	validation_1-error:0.05
# [3]	validation_0-error:0.03794	validation_1-error:0.05
# [4]	validation_0-error:0.03794	validation_1-error:0.05
# [5]	validation_0-error:0.03794	validation_1-error:0.05
# [6]	validation_0-error:0.03794	validation_1-error:0.05
# [7]	validation_0-error:0.03794	validation_1-error:0.05
# [8]	validation_0-error:0.03794	validation_1-error:0.05
# [9]	validation_0-error:0.03794	validation_1-error:0.05
# [10]	validation_0-error:0.03252	validation_1-error:0.05
# [11]	validation_0-error:0.03252	validation_1-error:0.05
# [12]	validation_0-error:0.03523	validation_1-error:0.045
# [13]	validation_0-error:0.03794	validation_1-error:0.045
# [14]	validation_0-error:0.03523	validation_1-error:0.045
# [15]	validation_0-error:0.03252	validation_1-error:0.05
# [16]	validation_0-error:0.02981	validation_1-error:0.05
# [17]	validation_0-error:0.02981	validation_1-error:0.05
# [18]	validation_0-error:0.02981	validation_1-error:0.05
# [19]	validation_0-error:0.02981	validation_1-error:0.045
# [20]	validation_0-error:0.02981	validation_1-error:0.045
# [21]	validation_0-error:0.0271	validation_1-error:0.05
# [22]	validation_0-error:0.0271	validation_1-error:0.045
# [23]	validation_0-error:0.0271	validation_1-error:0.045
# [24]	validation_0-error:0.0271	validation_1-error:0.045
# [25]	validation_0-error:0.02439	validation_1-error:0.045
# [26]	validation_0-error:0.02439	validation_1-error:0.045
# [27]	validation_0-error:0.02439	validation_1-error:0.045
# [28]	validation_0-error:0.02439	validation_1-error:0.045
# [29]	validation_0-error:0.02168	validation_1-error:0.045
# [30]	validation_0-error:0.02168	validation_1-error:0.045
# [31]	validation_0-error:0.02168	validation_1-error:0.045
# [32]	validation_0-error:0.02168	validation_1-error:0.045
# [33]	validation_0-error:0.02168	validation_1-error:0.045
# [34]	validation_0-error:0.02168	validation_1-error:0.045
# [35]	validation_0-error:0.02168	validation_1-error:0.045
# [36]	validation_0-error:0.02168	validation_1-error:0.045
# [37]	validation_0-error:0.02168	validation_1-error:0.045
# [38]	validation_0-error:0.02168	validation_1-error:0.045
# [39]	validation_0-error:0.02168	validation_1-error:0.05
# [40]	validation_0-error:0.02168	validation_1-error:0.05
# [41]	validation_0-error:0.02168	validation_1-error:0.05
# [42]	validation_0-error:0.02168	validation_1-error:0.05
# [43]	validation_0-error:0.02168	validation_1-error:0.05
# [44]	validation_0-error:0.01897	validation_1-error:0.05
# [45]	validation_0-error:0.01897	validation_1-error:0.05
# [46]	validation_0-error:0.01897	validation_1-error:0.05
# [47]	validation_0-error:0.01897	validation_1-error:0.05
# [48]	validation_0-error:0.01897	validation_1-error:0.05
# [49]	validation_0-error:0.01897	validation_1-error:0.05
# [50]	validation_0-error:0.01897	validation_1-error:0.05
# [51]	validation_0-error:0.01897	validation_1-error:0.05
# [52]	validation_0-error:0.01897	validation_1-error:0.045
# [53]	validation_0-error:0.01897	validation_1-error:0.045
# [54]	validation_0-error:0.01897	validation_1-error:0.045
# [55]	validation_0-error:0.01897	validation_1-error:0.045
# [56]	validation_0-error:0.01897	validation_1-error:0.045
# [57]	validation_0-error:0.01897	validation_1-error:0.045
# [58]	validation_0-error:0.01897	validation_1-error:0.045
# [59]	validation_0-error:0.01897	validation_1-error:0.045
# [60]	validation_0-error:0.01897	validation_1-error:0.045
# [61]	validation_0-error:0.01897	validation_1-error:0.045
# [62]	validation_0-error:0.01897	validation_1-error:0.045
# [63]	validation_0-error:0.01897	validation_1-error:0.045
# [64]	validation_0-error:0.01897	validation_1-error:0.045
# [65]	validation_0-error:0.01897	validation_1-error:0.045
# [66]	validation_0-error:0.01897	validation_1-error:0.045
# [67]	validation_0-error:0.01626	validation_1-error:0.045
# [68]	validation_0-error:0.01626	validation_1-error:0.045
# [69]	validation_0-error:0.01626	validation_1-error:0.045
# [70]	validation_0-error:0.01626	validation_1-error:0.045
# [71]	validation_0-error:0.01626	validation_1-error:0.045
# [72]	validation_0-error:0.01626	validation_1-error:0.045
# [73]	validation_0-error:0.01626	validation_1-error:0.045
# [74]	validation_0-error:0.01626	validation_1-error:0.045
# [75]	validation_0-error:0.01626	validation_1-error:0.045
# [76]	validation_0-error:0.01626	validation_1-error:0.045
# [77]	validation_0-error:0.01626	validation_1-error:0.045
# [78]	validation_0-error:0.01626	validation_1-error:0.045
# [79]	validation_0-error:0.01626	validation_1-error:0.045
# [80]	validation_0-error:0.01626	validation_1-error:0.045
# [81]	validation_0-error:0.01626	validation_1-error:0.04
# [82]	validation_0-error:0.01626	validation_1-error:0.04
# [83]	validation_0-error:0.01626	validation_1-error:0.05
# [84]	validation_0-error:0.01626	validation_1-error:0.05
# [85]	validation_0-error:0.01626	validation_1-error:0.05
# [86]	validation_0-error:0.01626	validation_1-error:0.05
# [87]	validation_0-error:0.01626	validation_1-error:0.055
# [88]	validation_0-error:0.01626	validation_1-error:0.05
# [89]	validation_0-error:0.01626	validation_1-error:0.05
# [90]	validation_0-error:0.01626	validation_1-error:0.05
# [91]	validation_0-error:0.01626	validation_1-error:0.045
# [92]	validation_0-error:0.01626	validation_1-error:0.05
# [93]	validation_0-error:0.01626	validation_1-error:0.055
# [94]	validation_0-error:0.01626	validation_1-error:0.05
# [95]	validation_0-error:0.01626	validation_1-error:0.05
# [96]	validation_0-error:0.01626	validation_1-error:0.05
# [97]	validation_0-error:0.01626	validation_1-error:0.05
# [98]	validation_0-error:0.01626	validation_1-error:0.055
# [99]	validation_0-error:0.01626	validation_1-error:0.055
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
# Plot and display the performance evaluation
xgb_eval = xgb_model.evals_result()
eval_steps = range(len(xgb_eval['validation_0']['error']))

fig, ax = plt.subplots(1, 1, sharex=True, figsize=(8, 6))

ax.plot(eval_steps, [1-x for x in xgb_eval['validation_0']['error']], label='Train')
ax.plot(eval_steps, [1-x for x in xgb_eval['validation_1']['error']], label='Test')
ax.legend()
ax.set_title('Accuracy')
ax.set_xlabel('Number of iterations')
# Out:
# Exception ignored in: <bound method DMatrix.__del__ of <xgboost.core.DMatrix object at 0x7fa229a916d8>>
# Traceback (most recent call last):
#   File "/opt/conda/envs/Python-3.6/lib/python3.6/site-packages/xgboost/core.py", line 482, in __del__
#     if self.handle is not None:
# AttributeError: 'DMatrix' object has no attribute 'handle'
# Exception ignored in: <bound method DMatrix.__del__ of <xgboost.core.DMatrix object at 0x7fa2296f73c8>>
# Traceback (most recent call last):
#   File "/opt/conda/envs/Python-3.6/lib/python3.6/site-packages/xgboost/core.py", line 482, in __del__
#     if self.handle is not None:
# AttributeError: 'DMatrix' object has no attribute 'handle'
# Text(0.5, 0, 'Number of iterations')

# %%
# Select trained model.
n_trees = 40
y_pred = xgb_model.predict(X_test, ntree_limit= n_trees)

# %%
# Check the accuracy of the trained model.
accuracy = accuracy_score(y_test, y_pred)

print('Accuracy: %.2f%%' % (accuracy * 100.0))
# Out:
# Accuracy: 95.00%

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
plt.matshow(cm)
plt.colorbar()
plt.xlabel('Actual values')
plt.ylabel('Predicted values')
plt.show()
pd.DataFrame(cm)
# Out:
#      0   1
# 0  123   3
# 1    7  67

# %%
y_pred_prob = xgb_model.predict_proba(X_test)

# ROC-AUC curve
from sklearn.metrics import roc_curve

fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob[:, 1])
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# Out:
# Text(0, 0.5, 'True Positive Rate')
